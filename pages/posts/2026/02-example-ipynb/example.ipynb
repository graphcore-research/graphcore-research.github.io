# %% [markdown]
# ---
# title: "Example notebook, about many things, and about nothing"
# date: 2026-02-01
# categories: ["Articles"]
# authors: [douglaso]
# tags:
#   - example
# slug: example-notebook
# ---
#
# Write posts as notebooks, with the same markdown features as blog posts.
#
# <!-- more -->
#
# Note that the notebook should start with a markdown cell with the applicable front matter (see above).
#
# ## Markdown content
#
# Equations $y = 2 \cdot x^2$,
#
# $$
# z = x^3 \qquad \text{ block equations}
# $$
#
# inline `code` and
#
# ```c++
# __attribute__((noinline)) void code() { }
# ```
#
# <p markdown>HTML with **markdown**.</p>
#
# Images:
#
# ![Linked images](edge_patterns.png){ style="width:20em" }

# %% [markdown]
# ## Code visibility
#
# By default, code cells are NOT shown.

# %%
# This code isn't shown
FOO = 123

# %%
def tag_to_show_code():
    # The tag "show_input" causes this cell's input to be shown
    pass

# %%
# SHOW_INPUT
# If the first line ends with SHOW_INPUT, the remaining input is shown
print("go! " * 10)
# Out:
# going! going! going! going! going! going! going! going! going! going!

# %% [markdown]
# ## Outputs

# %%
from IPython.display import SVG

display(SVG('''
<svg width="100" height="100" xmlns="http://www.w3.org/2000/svg">
    <circle cx="50" cy="50" r="40" fill="blue" />
    <rect x="10" y="10" width="30" height="30" fill="red" />
    <line x1="0" y1="0" x2="100" y2="100" stroke="green" stroke-width="2" />
</svg>
'''))

# %%
import matplotlib.pyplot as plt
import numpy as np

rs = np.linspace(0, 2 * np.pi, 1000)
plt.figure(figsize=(3, 3))
plt.plot(np.cos(rs), np.sin(rs));
